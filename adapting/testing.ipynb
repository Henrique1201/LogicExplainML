# %%
from function import XGBoostExplainer

explainer = XGBoostExplainer.load("explainer.pkl")
explainer.fit()
#Aqui em ordem sua entrada
xtest = [0.000, 1.623, 2.900, 3.900, 3.100, 0.000, 0.000, 1.000, 0.000, 0.000,]
print(explainer.explain(xtest))
print("delta=", explainer.explain_range(xtest))
# Out:
# [EVTotal == 1.623, TVMNS.1 == 0]
# delta= ['126.0 <= EVTotal <= 1649.99', 'TVMNS.1 == 0']
